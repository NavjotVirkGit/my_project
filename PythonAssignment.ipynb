# %% [markdown]
# # Data Exploration and cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import libraries and dataset
df1= pd.read_csv("HospInfo.csv", index_col=0)
df1.head()
# Out:
#                               Hospital Name                     Address  \
# Provider ID
# 10005         MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 10012        DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE
# 10032                      WEDOWEE HOSPITAL       209 NORTH MAIN STREET
# 10095                  HALE COUNTY HOSPITAL            508 GREEN STREET
# 10131              CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE
#
#                    City State  ZIP Code County Name  Phone Number  \
# Provider ID
# 10005              BOAZ    AL     35957    MARSHALL    2565938310
# 10012        FORT PAYNE    AL     35968     DE KALB    2568453150
# 10032           WEDOWEE    AL     36278    RANDOLPH    2563572111
# 10095        GREENSBORO    AL     36744        HALE    3346243024
# 10131        HUNTSVILLE    AL     35801     MADISON    2568823100
#
#                     Hospital Type  \
# Provider ID
# 10005        Acute Care Hospitals
# ...

# %%
df2= pd.read_csv("us_hospital_locations.csv", index_col=0)
df2.head()
# Out:
#                           Y  FID        ID  \
# X
# -1.331889e+07  4.346975e+06    1   5793230
# -1.322651e+07  4.049626e+06    2  53391362
# -1.315620e+07  4.031978e+06    3  11190023
# -1.317190e+07  4.041752e+06    4  17090028
# -1.313208e+07  4.037270e+06    5  23691706
#
#                                                             NAME  \
# X
# -1.331889e+07                    CENTRAL VALLEY GENERAL HOSPITAL
# -1.322651e+07  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# -1.315620e+07                  EAST LOS ANGELES DOCTORS HOSPITAL
# -1.317190e+07          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# -1.313208e+07                      KINDRED HOSPITAL BALDWIN PARK
#
#                                  ADDRESS             CITY STATE    ZIP  \
# X
# -1.331889e+07    1025 NORTH DOUTY STREET          HANFORD    CA  93230
# -1.322651e+07             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362
# -1.315620e+07    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023
# ...

# %%
df1.shape
#check the shape of datasets
# Out:
# (4812, 28)

# %%
df2.shape
# Out:
# (7596, 33)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4812 entries, 10005 to 490053
# Data columns (total 28 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Hospital Name                                                  4812 non-null   object
#  1   Address                                                        4812 non-null   object
#  2   City                                                           4812 non-null   object
#  3   State                                                          4812 non-null   object
#  4   ZIP Code                                                       4812 non-null   int64
#  5   County Name                                                    4797 non-null   object
#  6   Phone Number                                                   4812 non-null   int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 7596 entries, -13318894.7592 to -12449213.0694
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Y           7596 non-null   float64
#  1   FID         7596 non-null   int64
#  2   ID          7596 non-null   int64
#  3   NAME        7596 non-null   object
#  4   ADDRESS     7596 non-null   object
#  5   CITY        7596 non-null   object
#  6   STATE       7596 non-null   object
#  7   ZIP         7596 non-null   int64
#  8   ZIP4        7596 non-null   object
#  9   TELEPHONE   7596 non-null   object
#  10  TYPE        7596 non-null   object
#  11  STATUS      7596 non-null   object
#  12  POPULATION  7596 non-null   int64
#  13  COUNTY      7596 non-null   object
#  14  COUNTYFIPS  7596 non-null   object
#  15  COUNTRY     7596 non-null   object
#  16  LATITUDE    7596 non-null   float64
#  17  LONGITUDE   7596 non-null   float64
# ...

# %% [markdown]
# # Data Aggregating

# %%
new_df2 = pd.DataFrame(df2, columns = ['NAME', 'ADDRESS','BEDS','LATITUDE','LONGITUDE'])

# %%
new_df2.columns = ['Hospital Name','Address','Beds','Latitude','Longitude']
new_df2.head()
# Out:
#                                                    Hospital Name  \
# X
# -1.331889e+07                    CENTRAL VALLEY GENERAL HOSPITAL
# -1.322651e+07  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# -1.315620e+07                  EAST LOS ANGELES DOCTORS HOSPITAL
# -1.317190e+07          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# -1.313208e+07                      KINDRED HOSPITAL BALDWIN PARK
#
#                                  Address  Beds   Latitude   Longitude
# X
# -1.331889e+07    1025 NORTH DOUTY STREET    49  36.336159 -119.645667
# -1.322651e+07             150 VIA MERIDA    62  34.154939 -118.815736
# -1.315620e+07    4060 WHITTIER BOULEVARD   127  34.023647 -118.184165
# -1.317190e+07     6245 DE LONGPRE AVENUE   100  34.096391 -118.325235
# -1.313208e+07  14148 FRANCISQUITO AVENUE    95  34.063039 -117.967438

# %%
df = new_df2.merge(df1) #combine both of the dataset using merge operation, using name and address of the hospital

# %%
df
# Out:
#                                  Hospital Name                    Address  \
# 0             SALINAS VALLEY MEMORIAL HOSPITAL        450 EAST ROMIE LANE
# 1                       COLLEGE MEDICAL CENTER        2776 PACIFIC AVENUE
# 2     KAISER FOUNDATION HOSPITAL - SAN LEANDRO         2500 MERCED STREET
# 3             PINCKNEYVILLE COMMUNITY HOSPITAL       5383 STATE ROUTE 154
# 4              ST JOSEPH'S HOSPITAL - SAVANNAH      11705 MERCY BOULEVARD
# ...                                        ...                        ...
# 1883               PHOEBE WORTH MEDICAL CENTER  807 SOUTH ISABELLA STREET
# 1884                    SELBY GENERAL HOSPITAL        1106 COLEGATE DRIVE
# 1885        UNIVERSITY OF MISSOURI HEALTH CARE         ONE HOSPITAL DRIVE
# 1886                        SGMC LANIER CAMPUS    116 WEST THIGPEN AVENUE
# 1887        OWENSBORO HEALTH REGIONAL HOSPITAL  1201 PLEASANT VALLEY ROAD
#
#       Beds   Latitude   Longitude           City State  ZIP Code  County Name  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                  Hospital Name                    Address  \
# 0             SALINAS VALLEY MEMORIAL HOSPITAL        450 EAST ROMIE LANE
# 1                       COLLEGE MEDICAL CENTER        2776 PACIFIC AVENUE
# 2     KAISER FOUNDATION HOSPITAL - SAN LEANDRO         2500 MERCED STREET
# 3             PINCKNEYVILLE COMMUNITY HOSPITAL       5383 STATE ROUTE 154
# 4              ST JOSEPH'S HOSPITAL - SAVANNAH      11705 MERCY BOULEVARD
# ...                                        ...                        ...
# 1883               PHOEBE WORTH MEDICAL CENTER  807 SOUTH ISABELLA STREET
# 1884                    SELBY GENERAL HOSPITAL        1106 COLEGATE DRIVE
# 1885        UNIVERSITY OF MISSOURI HEALTH CARE         ONE HOSPITAL DRIVE
# 1886                        SGMC LANIER CAMPUS    116 WEST THIGPEN AVENUE
# 1887        OWENSBORO HEALTH REGIONAL HOSPITAL  1201 PLEASANT VALLEY ROAD
#
# ...

# %%
df.isna().sum() #checking the null values in final dataset
# Out:
# Hospital Name                                                       0
# Address                                                             0
# Beds                                                                0
# Latitude                                                            0
# Longitude                                                           0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                         5
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# ...

# %%
#dropping the features that are not required 
df= df.drop(['Meets criteria for meaningful use of EHRs','Hospital overall rating footnote','Mortality national comparison footnote','Safety of care national comparison footnote','Readmission national comparison footnote','Patient experience national comparison footnote','Effectiveness of care national comparison footnote','Timeliness of care national comparison footnote','Efficient use of medical imaging national comparison footnote','Mortality national comparison','Safety of care national comparison','Readmission national comparison','Patient experience national comparison','Effectiveness of care national comparison','Timeliness of care national comparison','Efficient use of medical imaging national comparison','County Name'], axis=1, inplace= False)
df
# Out:
#                                  Hospital Name                    Address  \
# 0             SALINAS VALLEY MEMORIAL HOSPITAL        450 EAST ROMIE LANE
# 1                       COLLEGE MEDICAL CENTER        2776 PACIFIC AVENUE
# 2     KAISER FOUNDATION HOSPITAL - SAN LEANDRO         2500 MERCED STREET
# 3             PINCKNEYVILLE COMMUNITY HOSPITAL       5383 STATE ROUTE 154
# 4              ST JOSEPH'S HOSPITAL - SAVANNAH      11705 MERCY BOULEVARD
# ...                                        ...                        ...
# 1883               PHOEBE WORTH MEDICAL CENTER  807 SOUTH ISABELLA STREET
# 1884                    SELBY GENERAL HOSPITAL        1106 COLEGATE DRIVE
# 1885        UNIVERSITY OF MISSOURI HEALTH CARE         ONE HOSPITAL DRIVE
# 1886                        SGMC LANIER CAMPUS    116 WEST THIGPEN AVENUE
# 1887        OWENSBORO HEALTH REGIONAL HOSPITAL  1201 PLEASANT VALLEY ROAD
#
#       Beds   Latitude   Longitude           City State  ZIP Code  \
# ...

# %%
df.isna().sum() #checking the null values after dropping rows
# Out:
# Hospital Name              0
# Address                    0
# Beds                       0
# Latitude                   0
# Longitude                  0
# City                       0
# State                      0
# ZIP Code                   0
# Phone Number               0
# Hospital Type              0
# Hospital Ownership         0
# Emergency Services         0
# Hospital overall rating    0
# Location                   0
# dtype: int64

# %%
#check the duplicate values in the dataset
duplicate = df[df.duplicated()]

# %%
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [Hospital Name, Address, Beds, Latitude, Longitude, City, State, ZIP Code, Phone Number, Hospital Type, Hospital Ownership, Emergency Services, Hospital overall rating, Location]
# Index: []

# %%
#renaming the features of the dataset to remove spaces and capital letters
df.columns = ['Hospital_Name','Address','Beds','Latitude','Longitude','City','State','Zip_code','Phno','Htype','Hown','Emergency_service','rating','Location']

# %%
df
# Out:
#                                  Hospital_Name                    Address  \
# 0             SALINAS VALLEY MEMORIAL HOSPITAL        450 EAST ROMIE LANE
# 1                       COLLEGE MEDICAL CENTER        2776 PACIFIC AVENUE
# 2     KAISER FOUNDATION HOSPITAL - SAN LEANDRO         2500 MERCED STREET
# 3             PINCKNEYVILLE COMMUNITY HOSPITAL       5383 STATE ROUTE 154
# 4              ST JOSEPH'S HOSPITAL - SAVANNAH      11705 MERCY BOULEVARD
# ...                                        ...                        ...
# 1883               PHOEBE WORTH MEDICAL CENTER  807 SOUTH ISABELLA STREET
# 1884                    SELBY GENERAL HOSPITAL        1106 COLEGATE DRIVE
# 1885        UNIVERSITY OF MISSOURI HEALTH CARE         ONE HOSPITAL DRIVE
# 1886                        SGMC LANIER CAMPUS    116 WEST THIGPEN AVENUE
# 1887        OWENSBORO HEALTH REGIONAL HOSPITAL  1201 PLEASANT VALLEY ROAD
#
#       Beds   Latitude   Longitude           City State  Zip_code        Phno  \
# ...

# %% [markdown]
# # Data Visualization

# %%
import numpy as np
X = np.array(df[['Latitude','Longitude']], dtype = 'float64')

# %%
plt.scatter(X[:,0],X[:,1] , alpha = 0.2, s=50)

# %%
df.dtypes #checking the types of the attributes
# Out:
# Hospital_Name         object
# Address               object
# Beds                   int64
# Latitude             float64
# Longitude            float64
# City                  object
# State                 object
# Zip_code               int64
# Phno                   int64
# Htype                 object
# Hown                  object
# Emergency_service       bool
# rating                object
# Location              object
# dtype: object

# %%
df.head()
# Out:
#                               Hospital_Name                Address  Beds  \
# 0          SALINAS VALLEY MEMORIAL HOSPITAL    450 EAST ROMIE LANE   269
# 1                    COLLEGE MEDICAL CENTER    2776 PACIFIC AVENUE   121
# 2  KAISER FOUNDATION HOSPITAL - SAN LEANDRO     2500 MERCED STREET   216
# 3          PINCKNEYVILLE COMMUNITY HOSPITAL   5383 STATE ROUTE 154    17
# 4           ST JOSEPH'S HOSPITAL - SAVANNAH  11705 MERCY BOULEVARD   294
#
#     Latitude   Longitude           City State  Zip_code        Phno  \
# 0  36.659030 -121.645984        SALINAS    CA     93901  8317574333
# 1  33.807093 -118.193390     LONG BEACH    CA     90806  5625951911
# 2  37.706406 -122.164655    SAN LEANDRO    CA     94577  5104541000
# 3  38.084846  -89.349108  PINCKNEYVILLE    IL     62274  6183572187
# 4  31.985430  -81.154556       SAVANNAH    GA     31419  9128194100
#
#                        Htype                                         Hown  \
# ...

# %% [markdown]
# # Plotting map

# %%
# !pip install folium
# Out:
# ...
#   Using cached branca-0.4.2-py3-none-any.whl (24 kB)
# ...

# %%
import folium
import re
m = folium.Map(location=[df.Latitude.mean(), df.Longitude.mean()], zoom_start = 9, tiles = 'Stamen Toner')

for _, row in df.iterrows():
    folium.CircleMarker(
      location = [row.Latitude,row.Longitude],
      radius = 5,
      popup = re.sub(r'[^a-zA-Z]+','',row.Address),
      colors = '#1787FE',
      fill =True,
      fill_colors= '#1787FE'

  ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Running K-Means Algorithm

# %%
from sklearn.cluster import KMeans
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = df[['Latitude']]
X_axis = df[['Longitude']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init ='k-means++')
kmeans.fit(df[df.columns[3:5]]) # Compute k-means clustering.
df['cluster_label'] = kmeans.fit_predict(df[df.columns[3:5]])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(df[df.columns[3:5]]) # Labels of each point
df.head(10)
# Out:
#                               Hospital_Name                        Address  \
# 0          SALINAS VALLEY MEMORIAL HOSPITAL            450 EAST ROMIE LANE
# 1                    COLLEGE MEDICAL CENTER            2776 PACIFIC AVENUE
# 2  KAISER FOUNDATION HOSPITAL - SAN LEANDRO             2500 MERCED STREET
# 3          PINCKNEYVILLE COMMUNITY HOSPITAL           5383 STATE ROUTE 154
# 4           ST JOSEPH'S HOSPITAL - SAVANNAH          11705 MERCY BOULEVARD
# 5             UPSON REGIONAL MEDICAL CENTER            801 W GORDON STREET
# 6              PHOEBE SUMTER MEDICAL CENTER              126 HIGHWAY 280 W
# 7                      RIPON MEDICAL CENTER                845 PARKSIDE ST
# 8                    SCRIPPS GREEN HOSPITAL  10666 NORTH TORREY PINES ROAD
# 9     SCRIPPS MEMORIAL HOSPITAL - ENCINITAS             354 SANTA FE DRIVE
#
#    Beds   Latitude   Longitude           City State  Zip_code        Phno  \
# ...

# %%
#plotting clusters after running K-means
df.plot.scatter(x = 'Latitude', y = 'Longitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
#creating functions to create map as per the user input
cols = ['#e6194b','#3cb44b','#ffe119','#4363d8']

def checkcity(cityval):
    
    for index, row in df.iterrows():
        if row['City'] == cityval:
            x = row['Latitude']
            y = row['Longitude']
    m = create_map(df, 'cluster_label',cityval,x,y)
    return m

def create_map(df, cluster_label,cityval,x,y):
    m = folium.Map(location=[x, y], zoom_start = 9, tiles = 'Stamen Toner')
  
  
    for _, row in df.iterrows():
    
        if row.City == cityval:
        
            color_dict = {0: 'lightblue', 1: 'lightgreen', 2: 'orange', 3: 'red'}

            mystring = 'Name of the Hospital:{}, Type of the Hospital: {}, Available bed in Hospital:{}'.format(row.Hospital_Name, row.Htype, row.Beds)

            folium.CircleMarker(
              location = [row.Latitude,row.Longitude],
              radius = 5,
              popup = mystring,
              columns = ['City', 'Zip_code'],
              colors = color_dict,
              tooltip='Click here to see Popup',
              fill =True,
              key_on=df.City,
              fill_colors= color_dict,
              legend_name = 'Number of Hospital per City'
      
            ).add_to(m)
  
    return m

# %%
#checking the best clusters and silhoutte score
from tqdm import tqdm
from sklearn.metrics import silhouette_score
best_silhouette, best_k = 0,1

for k in tqdm(range(2,100)):
  model = KMeans(n_clusters=k, random_state=1).fit(X)
  class_predictions = model.predict(X)


  curr_silhouette = silhouette_score(X, class_predictions)
  if curr_silhouette>best_silhouette:
    best_k = k
    best_silhouette = curr_silhouette

print(f'k = {best_k}')
print(f'Silhouette Score: {best_silhouette}')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 98/98 [01:17<00:00,  1.27it/s]
# k = 3
# Silhouette Score: 0.5527282517660309

# %% [markdown]
# # GUI Programming

# %%
#creating list of cities as per the state selected by the user 
def get_cities():
    
    cities_based_on_state = []
    
    cities = df.iloc[:, 5].values.tolist()
    unique_cities = set(cities)
    cities_based_on_state = list(unique_cities)
    return cities_based_on_state

# %%
from tkinter import *
import tkinter as tk
from tkinter import ttk
from tkinter.ttk import *
 

    
    
# creates a Tk() object
root = Tk()

 
# sets the geometry of main
# root window
root.geometry("660x550")
 

# function to open a new window


def openNewWindow():
    #creating error screen to pop up the empty entrybox
    if e1.index("end") == 0 and e2.index("end") == 0 and combo1.index("end") == 0 and combo2.index("end") == 0:
        newWindow = Toplevel(root)
        newWindow.geometry("100x100")
        
        Label(newWindow,
          text ="Enter all the values").pack()
    
     
    # Toplevel object which will
    # be treated as a new window
    else:
        cityval = combo2.get()
        
        from IPython.display import display
        from IPython.display import HTML
        import webbrowser, os
        
        m = checkcity(cityval)
        
        #calling map function to fit map into browser
       
        
    
        m.save('plot_data.html')
        webbrowser.open('plot_data.html')
        
        
        
        
        



root.title("EazeCare")
root.configure(bg="lavender")
root['padx'] = 20
label00 = tk.Label(root, text="GEOLOCATION HOSPITAL FINDER MODEL", font=('Times', 18), bg='pink')
label00.grid(row=0, column=2, columnspan=6)

label0 = tk.Label(root, text="Enter details to find Hospitals", font=('Times', 13), bg='lavender')
label0.grid(row=10, column=1, columnspan=6)

list_of_cities = get_cities()
combo2 = ttk.Combobox(root, values=list_of_cities)
combo2.grid(row=13, column =2, pady=5)


label1 = tk.Label(root, text='First Name').grid(row=11, column = 1)
label2 = tk.Label(root, text='Last Name').grid(row=12, column = 1)

label4 = tk.Label(root, text='Select the City').grid(row=13, column = 1)


 


e1 = Entry(root, width=20)
e2 = Entry(root, width=20)



e1.grid(row=11, column=2, pady=5)
e2.grid(row=12, column=2, pady=5)


button = tk.Button(root, text='OK', width=25, command = openNewWindow).grid(row=16,column=2, pady=10, padx=50)


 
# mainloop, runs infinitely
mainloop()
